# %%
import os

# %%
for path, subdirs, files in os.walk('/home/jheuristic/data/pickles/'):
    for file in files:
        there_is_wav=False
        for path1, subdirs1, files1 in os.walk('/home/jheuristic/data/wav/'):
            for file1 in files1:
                if(file1[:-3]==file[:-3])
                    there_is_wav=True
        if(not there_is_wav):
            #os.remove(path+file)
            print(666)

# %%
for path1, subdirs1, files1 in os.walk('/home/jheuristic/data/wav/'):
    for file1 in files1:
        print(file1[:-3])
# Out:
# 012006b_.mid.
# 007011b_.mid.
# 011704v1.mid.
# 027300b_.mid.
# 008107b_.mid.
# 025300b_.mid.
# 028900b_.mid.
# 006606b_.mid.
# 011007b_.mid.
# 004311b_.mid.
# 024842b4.mid.
# 040500b_.mid.
# 013Xylophone.mid.
# 024454b_.mid.
# 00cj.mid.
# 007408b_.mid.
# 034500b_.mid.
# 01hcgmh.mid.
# 026400b_.mid.
# 011506b_.mid.
# 017106b_.mid.
# 03_A_Rolling_Dub.mid.
# 007305bv.mid.
# 02_Chasing_the_Dragon.mid.
# 024444b_.mid.
# x-men-magnetos_theme.mid.
# 031GuitarHarmonics.mid.
# 036400b_.mid.
# 01_Surely_Dubbing.mid.
# 003806b_.mid.
# 023TangoAcordian.mid.
# 030300b_.mid.
# 01yb.mid.
# 016606b_.mid.
# 03_Dub_Servant.mid.
# 035500b_.mid.
# 00iclartl.mid.
# 006005b_.mid.
# 02itgost.mid.
# 024817b2.mid.
# 02utbt.mid.
# 006502b_.mid.
# 00pmaiar.mid.
# 005206b_.mid.
# 024514b_.mid.
# 005ElPiano2.mid.
# 011506bv.mid.
# 031300b_.mid.
# 032500b_.mid.
# 00abiagc.mid.
# 017906b_.mid.
# 010207b_.mid.
# 007607b_.mid.
# 01.
# 016206b_.mid.
# 024503b_.mid.
# 008807b_.mid.
# 011106b_.mid.
# 006Harpsichord.mid.
# 025600b_.mid.
# 004803b_.mid.
# 018405b_.mid.
# 027100b_.mid.
# 024522b_.mid.
# 010107b_.mid.
# 029400b_.mid.
# 03_Raise_your_conscious_High.mid.
# 010406b_.mid.
# 029200b_.mid.
# 027200b_.mid.
# 037800b_.mid.
# 027800b_.mid.
# 027400b_.mid.
# 007903b_.mid.
# 013703b_.mid.
# 00tbatg.mid.
# 039400b_.mid.
# 024415b_.mid.
# 017705bv.mid.
# 014706b_.mid.
# 03_Mussolini_could_not_win.mid.
# 031200b_.mid.
# 006906b_.mid.
# 007507b_.mid.
# 035700b_.mid.
# 02BuySel.mid.
# 010806b_.mid.
# 006106b_.mid.
# 00ccc.mid.
# 015301b_.mid.
# 010406bv.mid.
# 024809bs.mid.
# 017206ch.mid.
# 022902b_.mid.
# 031900b_.mid.
# 038200b_.mid.
# 012106b_.mid.
# 039600b_.mid.
# 032200b_.mid.
# 010107bv.mid.
# 022Harmonica.mid.
# 019705b_.mid.
# 011704v2.mid.
# 025000b_.mid.
# 032600b_.mid.
# 032800b_.mid.
# 03_Hail_Bob_Marley_in_Dub.mid.
# 041600b_.mid.
# 003907b_.mid.
# 040FeatEricaBaxter_-_DreamsLostWitnessRemix__SamCera_20120708165703.mid.
# 02fg.mid.
# 032AcBass.mid.
# 01_Nimrods_Defeat.mid.
# 037000b_.mid.
# 00mpdt.mid.
# 039100b_.mid.
# 010006b_.mid.
# 018007b_.mid.
# 006206b_.mid.
# 033000b_.mid.
# 02_Warn_Dem_Dreadlocks.mid.
# 016106b_.mid.
# 011205b_.mid.
# 016406b_.mid.
# 028600b_.mid.
# 02ano.mid.
# 03_Behold_in_Dub.mid.
# 02_The_Jerusalem_Connection.mid.
# 015606b_.mid.
# 024505b_.mid.
# 030500b_.mid.
# 004003b_.mid.
# 040Violin.mid.
# -.
# 018405bv.mid.
# 038600b_.mid.
# 024462bv.mid.
# 039500b_.mid.
# 040800b_.mid.
# 018707b_.mid.
# 02because.mid.
# 007514b_.mid.
# 013807b_.mid.
# 041100b_.mid.
# Dreams.
# 014500ba.mid.
# 022602b_.mid.
# 004606bs.mid.
# 022707b_.mid.
# 004106b_.mid.
# 01sgmlwfed.mid.
# 012306b_.mid.
# 015408b_.mid.
# 035200b_.mid.
# 024537b_.mid.
# 02.
# 024446b_.mid.
# 038SynthBass1.mid.
# 026000b_.mid.
# 015905b_.mid.
# 022701b_.mid.
# 036100b_.mid.
# 019007ch.mid.
# 004106bs.mid.
# 006507b_.mid.
# 00ptb.mid.
# 019007b_.mid.
# 028200b_.mid.
# 00pat.mid.
# 027900b_.mid.
# 007206b_.mid.
# 022602bv.mid.
# 031800b_.mid.
# 036SlapBass1.mid.
# 033500b_.mid.
# 015505b_.mid.
# 013006b_.mid.
# 018007bv.mid.
# 029100b_.mid.
# 040400bv.mid.
# 01TimeLv.mid.
# 003706b_.mid.
# 01etpr.mid.
# 024805b1.mid.
# 007706b_.mid.
# 020ReedOrgan.mid.
# 01_Radical_Dub.mid.
# 01_Leave_Natty_Midi_Version.mid.
# 019707ba.mid.
# 008906b_.mid.
# 02tgw.mid.
# 024310b_.mid.
# 014001b_.mid.
# 00tmpm.mid.
# 025SteelAcGuitar.mid.
# 03_JAH_Servant.mid.
# 019ChurchOrgan.mid.
# 024429bb.mid.
# 025800b_.mid.
# 00tfc.mid.
# 033300b_.mid.
# 010306b_.mid.
# 026ElJazzGuitar.mid.
# 039200b_.mid.
# 012606bv.mid.
# 013701b_.mid.
# 017PercOrgan.mid.
# 040300b_.mid.
# 01_Menelik_Department.mid.
# Witness.
# 001BrtAcPiano.mid.
# 02oasa.mid.
# 012506b_.mid.
# 024864qt.mid.
# 030100b_.mid.
# 012805b_.mid.
# 029OdGuitar.mid.
# 006402b_.mid.
# 009801b_.mid.
# 041900b_.mid.
# 024410b_.mid.
# 027ElGuitar.mid.
# 006906ba.mid.
# 006206bv.mid.
# 02_Love_is_From_Jah.mid.
# 040_-_Ibiza_Dreams__J.D._20110615094526.mid.
# Christe.
# 040600b_.mid.
# 014403b_.mid.
# 032400b_.mid.
# 008707b_.mid.
# 035100b_.mid.
# 03Timer.mid.
# 03top.mid.
# 033800b_.mid.
# 014806bv.mid.
# 013506b_.mid.
# 040900bv.mid.
# 036600b_.mid.
# 041000b_.mid.
# 015105b_.mid.
# 034100b_.mid.
# 009106b_.mid.
# 013306b_.mid.
# 007011ch.mid.
# 039300b_.mid.
# 025700b_.mid.
# 008506b_.mid.
# 029000b_.mid.
# 024432b_.mid.
# 032000b_.mid.
# 015804b_.mid.
# 03utab.mid.
# 040.
# 024AcGuitar.mid.
# 007Clavichord.mid.
# 027500b_.mid.
# 037200b_.mid.
# 011308b_.mid.
# 019506b_.mid.
# 034900b_.mid.
# 014907b_.mid.
# 028300b_.mid.
# 009106ch.mid.
# 02empv.mid.
# 006704b_.mid.
# 000AcPiano.mid.
# 012905b_.mid.
# 03tabm.mid.
# 026200b_.mid.
# 038400b_.mid.
# 012Marimba.mid.
# 035000b_.mid.
# 018305b_.mid.
# 041700b_.mid.
# 040100b_.mid.
# 024828b3.mid.
# 029900b_.mid.
# 014608b_.mid.
# 00eomatt.mid.
# 034400b_.mid.
# 039000b_.mid.
# 033700b_.mid.
# 036900b_.mid.
# 037700b_.mid.
# 009507b_.mid.
# 007614b_.mid.
# 008606b_.mid.
# 02dwtwf.mid.
# 026800b_.mid.
# 005903b_.mid.
# 015403b_.mid.
# 011Vibraphone.mid.
# 041300b_.mid.
# 032900b_.mid.
# 030600b_.mid.
# 019406b_.mid.
# 032300b_.mid.
# 00gujal.mid.
# 037SlapBass2.mid.
# 004705b_.mid.
# 033400b_.mid.
# 015Dulcimer.mid.
# Feat.
# 040000b_.mid.
# 011704b_.mid.
# 03.
# 011407b_.mid.
# 009207b_.mid.
# 034600b_.mid.
# 01mlar.mid.
# Baxter.
# 028000b_.mid.
# 008305b_.mid.
# 041Viola.mid.
# 02iwwbbdch.mid.
# 014505b_.mid.
# 02_Dub_Dub_I_See.mid.
# 019710b_.mid.
# 024842bs.mid.
# 007807b_.mid.
# 008Celesta.mid.
# 03_I_and_I_Alternative_Version.mid.
# 012206b_.mid.
# 034800b_.mid.
# 034300b_.mid.
# 006408b_.mid.
# 017405b_.mid.
# 006707b_.mid.
# 014710b_.mid.
# 009906b_.mid.
# 03lluc.mid.
# 038500b_.mid.
# 024846b5.mid.
# 041500b_.mid.
# 024417b_.mid.
# 026100b_.mid.
# Menuet.mid.
# 014406b_.mid.
# 024403b_.mid.
# 022703b_.mid.
# 01ucvm.mid.
# 013906b_.mid.
# 036800b_.mid.
# 025200b_.mid.
# Remix).mid.
# 008405b_.mid.
# 014505bv.mid.
# 029500b_.mid.
# 037900b_.mid.
# 013702b_.mid.
# Kyrie.
# 033600b_.mid.
# 024853b5.mid.
# 014004b_.mid.
# 017507b_.mid.
# 038100b_.mid.
# 005505b_.mid.
# 010MusicBox.mid.
# 039SynthBass2.mid.
# 018806b_.mid.
# 016806b_.mid.
# 036700b_.mid.
# 030200b_.mid.
# 038700b_.mid.
# 032700b_.mid.
# 02abfa.mid.
# 009count.mid.
# 035600b_.mid.
# 028100b_.mid.
# 038300b_.mid.
# 019412b_.mid.
# 003HonkyTonkPiano.mid.
# 017705b_.mid.
# 028500b_.mid.
# 031400b_.mid.
# 015705b_.mid.
# 016506b_.mid.
# 033100b_.mid.
# 024528b_.mid.
# 00ismhutt.mid.
# 009209b_.mid.
# 034200b_.mid.
# 009709b_.mid.
# 033200b_.mid.
# 00atc.mid.
# 028800b_.mid.
# 004807b_.mid.
# 03tslr.mid.
# 024823b2.mid.
# 014TubularBells.mid.
# 037300b_.mid.
# 002ElGrandPiano.mid.
# 030700b_.mid.
# 004407b_.mid.
# 02bbwypch.mid.
# 009606b_.mid.
# 007305b_.mid.
# 010707b_.mid.
# 009Glockenspiel.mid.
# 016907b_.mid.
# 004207b_.mid.
# 03hiawatha.mid.
# 025400b_.mid.
# 037100b_.mid.
# 015309b_.mid.
# 038000b_.mid.
# 017807b_.mid.
# 00plg.mid.
# 037300bv.mid.
# 030400b_.mid.
# 009307b_.mid.
# 027000b_.mid.
# Eleison.
# 019406bv.mid.
# 02_Free_Up.mid.
# 029700b_.mid.
# 024440b_.mid.
# 01movh.mid.
# 012008ba.mid.
# 041200b_.mid.
# 042000b_.mid.
# 016DrawbarOrgan.mid.
# 022711b_.mid.
# 03bedelia.mid.
# 004606b_.mid.
# 024864bs.mid.
# 030000b_.mid.
# 024823bs.mid.
# 02_Lets_give_thanks_and_praise_in_Dub.mid.
# 040200b_.mid.
# 024515B_.mid.
# 040700b_.mid.
# 014907ch.mid.
# 01tttb.mid.
# 026500b_.mid.
# 013705b_.mid.
# 024833b3.mid.
# 007903bs.mid.
# 040900b_.mid.
# 012406b_.mid.
# 024511b_.mid.
# 024526b_.mid.
# 01hot.mid.
# 031700b_.mid.
# 003907bv.mid.
# 024540b_.mid.
# 00hm-rb.mid.
# 004ElPiano1.mid.
# 00tbbos.mid.
# 012705b_.mid.
# 02ttatp.mid.
# 007007b_.mid.
# 005605b_.mid.
# 009709ch.mid.
# 025900b_.mid.
# 034000b_.mid.
# 006906bav.mid.
# 038800b_.mid.
# 018RockOrgan.mid.
# 032100b_.mid.
# 028700b_.mid.
# 00tmom.mid.
# 035800b_.mid.
# 037400b_.mid.
# 010506b_.mid.
# 035900b_.mid.
# 026600b_.mid.
# 036300b_.mid.
# 024417bv.mid.
# 008008b_.mid.
# 009408b_.mid.
# 035FretlessBass.mid.
# 031100b_.mid.
# 038900b_.mid.
# 039800b_.mid.
# 034ElBassPick.mid.
# 036200b_.mid.
# 015305b_.mid.
# 029600b_.mid.
# 027600b_.mid.
# 031500b_.mid.
# 010602b_.mid.
# ].
# 014806b_.mid.
# 041800b_.mid.
# 03isaac.mid.
# 024415bv.mid.
# 01bw.mid.
# 036000b_.mid.
# 039900b_.mid.
# 030900b_.mid.
# 041400b_.mid.
# 017507ch.mid.
# .mid.
# 029300b_.mid.
# 024812b2.mid.
# 026700b_.mid.
# 02_Rok_wit_Mi_Earth_Rightful_Ruler_Remix.mid.
# 031600b_.mid.
# Ibiza.
# 033900b_.mid.
# 030DistGuitar.mid.
# 006404b_.mid.
# 025100b_.mid.
# 025500b_.mid.
# 00jbsmdgge.mid.
# 024835b3.mid.
# 035400b_.mid.
# 024437b_.mid.
# 024859b6.mid.
# 034700b_.mid.
# 021Accordian.mid.
# 028400b_.mid.
# 03ytfomhsa.mid.
# 029800b_.mid.
# 004507b_.mid.
# 039700b_.mid.
# 013705ch.mid.
# 004008b_.mid.
# 037500b_.mid.
# 01_Dreadlock_People.mid.
# 028ElMuteGuitar.mid.
# Dreams.mid.
# 00art.mid.
# 004006b_.mid.
# 03_Dance_Before_the_Throne.mid.
# 022709b_.mid.
# 017206b_.mid.
# 026900b_.mid.
# 024864b6.mid.
# 030800b_.mid.
# Erica.
# 02_Why_do_the_heathen_rage.mid.
# 035300b_.mid.
# 024809b1.mid.
# 011909b_.mid.
# 018506b_.mid.
# 024425b_.mid.
# 036500b_.mid.
# 027700b_.mid.
# 00sutb.mid.
# 026700ba.mid.
# 005708b_.mid.
# 01odtt.mid.
# 01_Visions_of_Jah.mid.
# 031000b_.mid.
# 009005b_.mid.
# 012606b_.mid.
# 017206vn.mid.
# 024462b_.mid.
# 024517b_.mid.
# 00gdg.mid.
# 013606b_.mid.
# 014007b_.mid.
# 01_Dont_worrie.mid.
# 037600b_.mid.
# 040400b_.mid.
# 00bb.mid.
# 033500bv.mid.
# 01_Ire_Times.mid.
# 017606b_.mid.
# 00tyats.mid.
# 011606b_.mid.
# 007906b_.mid.
# 033ElBassFinger.mid.
# 026300b_.mid.
